# %% [markdown]
# # Handiling missing values
# sklearn library is not capable of handling missing values

# %% [markdown]
# # Methodes
# 1. Removing row which contain missing values
# 2. Impute: a) univariate , b) MultivariateFill

# %% [markdown]
# # Univariate:
# 1. Numerical : mean/median/random/endofdis
# 2. cat : mode/missing
#
# # Multivatiate
# 1. Knn imputer
# 2. interative imputer (MICE)
