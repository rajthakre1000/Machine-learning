# %% [markdown]
# Types are :
# 1. Most Frequent
# 3. Missing (new Category)

# %% [markdown]
# Assumptions :
# 1. MCAR (Missing completly at random)
# 2. Mode should be way more than others

# %% [markdown]
# If More values missing or not MCAR
# 1. Make new category as [Missing]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'c:\Users\rajku\Downloads\train.csv', usecols=['GarageQual','FireplaceQu','SalePrice' ])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['GarageQual'] =='TA']['SalePrice'].plot(kind= 'kde', ax=ax)

df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde', color= 'red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with TA', 'Houses with NA']

ax.legend(lines, labels, loc='best')


plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
temp = df[df['GarageQual'] =='TA']['SalePrice']

# %%
# replacing missing values by mode values
df['GarageQual'].fillna('TA')
# Out:
# 0       TA
# 1       TA
# 2       TA
# 3       TA
# 4       TA
#         ..
# 1455    TA
# 1456    TA
# 1457    TA
# 1458    TA
# 1459    TA
# Name: GarageQual, Length: 1460, dtype: object

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

temp.plot(kind='kde', ax=ax)

df[df['GarageQual'] =='TA']['SalePrice'].plot(kind= 'kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed cariable']

ax.legend(lines, labels, loc='best')


plt.title('GarageQual')                 #graph overlap
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
