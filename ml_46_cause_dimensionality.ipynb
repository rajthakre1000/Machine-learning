# %% [markdown]
# ## Curse of Dimensionality
# * feature (dimensionals) -> optimal number of features, otherwise performance decreases
# * Optimal no. of Features

# %% [markdown]
# * ex- 28*28 picsal, 784 features if each picsal is a feature,
# * optimal number of picsal, then we get max accuracy
# * so not all features, and not very few features for best output

# %% [markdown]
# For High dimention- "Sparsity(distance btw data inc)" - when dimention increases then it becomes diff to find a point in n dimentions

# %% [markdown]
# Problems:
# * Performance decreases
# * Computation

# %% [markdown]
# Solution:
# * Dimention reduction;:
# 1. Feature selection : (forword selection, backword elemination)
# 2. Feature Extraction : (PCA, LDA, tSNE)

# %% [markdown]
# choose unit vactor so that, variance is maximum, after projection of points on unit vector,
