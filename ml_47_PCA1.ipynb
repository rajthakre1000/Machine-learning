# %% [markdown]
# # PCA
# * Unsupervised ML
# * complex maths, but useful

# %% [markdown]
# Higher dimention to lower dimention,
# * ex- capturing picture of 3D world and printing picture in 2D

# %% [markdown]
# Benifits  of PCA:
# 1. Higher dimention to lower dimention,
# 2. Faster exicution of algorithm.
# 3. visualization.

# %% [markdown]
# first do feature selection
# * if feature selection doesnt help(linery depend on both dimention) then which dimention to select??
# * In above condition we use Feature extraction (ex- we hav room, bathroom so we can't eleminate any one column, so we make new column "Size of room" and eleminate room, bathroom) to find price

# %% [markdown]
# Why Variance is Important?
# * variance measures how spread out data points are along a specific axis.
# * PCA's core goal is to reduce dimensionality while preserving as much variance (i.e., information) as possible.
# * The directions of maximum variance are your Principal Components (PCs)

# %% [markdown]
# Varience spread in x, y axis, differnciate btw two points, so on xaxis projection of all points actual distance in 2D section, in 1D it is compariable
