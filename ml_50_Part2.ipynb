# %% [markdown]
# ### Mathematical formulation of Linear Regression

# %% [markdown]
# cgpa    |   iq   | gender | LPA
# X1      X2  X2      X3      Y
#
# * let Y1 is the predicted value of LPA then,
# * Y' = b0 + b1x1 + b2x2 + b3x3

# %% [markdown]
# y1 = b0 + b1
# y2
# .
# .  =
# .
# .yn
